# %% [markdown]
# <a href="https://colab.research.google.com/github/chithira123/sample/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
image = cv2.imread("/content/three-girls-faces-close-up-4056707.webp")

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
print(f"Number of faces detected: {len(faces)}")
# Out:
# Number of faces detected: 3

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x534>
